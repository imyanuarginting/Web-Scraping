# %%
from googleapiclient.discovery import build

API_SERVICE_NAME = 'youtube'
API_VERSION = 'v3'
API_KEY = 'AIzaSyAaAks13A2icJ_rBRxEc_ESIZn2q9Wf8hQ'
VIDEO_ID = 'k0ubS6BhHu4'

# %%
youtube = build(
    API_SERVICE_NAME,
    API_VERSION,
    developerKey=API_KEY,
)

request = youtube.commentThreads().list(
    part='snippet',
    videoId=VIDEO_ID,
    maxResults=100, # range 1-100
)

response = request.execute()

comments = []
for item in response['items']:
  data = item['snippet']['topLevelComment']['snippet']
  comments.append([
      data['authorDisplayName'],
      data['publishedAt'],
      data['textOriginal'],
  ])

while True:
  nextPageToken = response['nextPageToken']

  nextRequest = youtube.commentThreads().list(
      part="snippet",
      videoId=VIDEO_ID,
      maxResults=100, # range 1-100
      pageToken=nextPageToken,
  )

  response = nextRequest.execute()

  for item in response['items']:
    data = item['snippet']['topLevelComment']['snippet']
    comments.append([
        data['authorDisplayName'],
        data['publishedAt'],
        data['textOriginal'],
    ])

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)

df = pd.DataFrame(
    comments,
    columns=['author', 'created_at', 'comment'],
)

df.shape
# Out:
# (23812, 3)

# %%
df.sample(5)
# Out:
#                          author            created_at  \
# 18446             @aesproject29  2024-12-30T11:54:47Z
# 19221  @willywildansolikhan3651  2024-12-28T17:56:16Z
# 22996         @kainagavesha3047  2024-12-21T06:19:23Z
# 14826             @MikoTiki-r8g  2025-01-06T14:43:48Z
# 164             @AdeSaputra-h5g  2025-03-16T07:07:52Z
#
#                                  comment
# 18446                  kacau si ni lagu🚀
# 19221        vibesnya kek tahun kapan ya
# 22996  WORTH TO WAITT KEREN BANGET COYYY
# 14826                Anjay dangdut gen z
# 164                         Aku dah lupa

# %%
df.to_csv('youtube_comments.csv', index=False, encoding='utf-8')
